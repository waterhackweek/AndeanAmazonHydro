# %%
# import things
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import geopandas as gpd
from pysheds.grid import Grid
import mplleaflet

# %%
# %matplotlib inline

# %%
# open DEM
grid = Grid.from_raster('/Users/sarah/whw2019_AndeanAmazonHydro/sa_acc_15s_grid/dem_latlon.tif', data_name='dem')

# %%
# try grid.size, grid.shape, etc
grid.size
# Out:
# 5964

# %%
# Get a view of the catchment
# this doesn't seem to work
view = grid.view('dem')

# %%
grid.read_raster('sa_acc_15s_grid/fd_latlon.tif', data_name='dir')

# %%
plt.imshow?

# %%
plt.imshow(grid.dir, cmap = 'YlGnBu')

# %%
#coordinates of one stream gage
x, y = -78.95333333, -0.314166667

grid.catchment(data='dir', x=x, y=y, dirmap=dirmap, out_name='catch',
               recursionlimit=15000, xytype='label', nodata_out=0)

# %%
grid.clip_to('catch')

# %%
demView = grid.view('dem', nodata=np.nan)
plotFigure(demView,'Elevation')

# %%
import gdal

# %%
plt.imshow(demView, cmap = 'YlGnBu')

# %%
# demview.shape is the shape of the bounding box; some of these pixels are nans.
demView[0:5, 0:5]
# Out:
# Raster([[nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan]], dtype=float32)

# %%
np.array?
#np.nanmin(demView)
#np.nanmean(demView)
#np.nanmax(demView)
